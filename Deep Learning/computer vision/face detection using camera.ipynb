# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Users\USER\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"


print(pytesseract.get_tesseract_version())
# Out:
# 5.5.0.20241111

# %%
import pytesseract

# Give full path to tesseract.exe


pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Test
from PIL import Image
img = Image.open("download.png")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Image To aa |
# Text
# Converter !
#
# Tools Be)

# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
import cv2

# 0 = default webcam, 1 = external webcam (if you have multiple)
cap = cv2.VideoCapture(0)

# Check if camera opened successfully
if not cap.isOpened():
    print("Cannot open camera")
    exit()
else:
    print("Camera opened:", cap.isOpened())
# Out:
# Camera opened: True

# %%
ret, frame= cap.read()
print("farme:",frame.shape)
# Out:
# farme: (480, 640, 3)

# %%
cv2.imwrite("snapshot.jpg", frame)
# Check shape
print(frame.shape)
# Out:
# (480, 640, 3)

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Frame", gray)

# %%
cv2.imshow('Color Camera', frame)

# %%
import matplotlib.pyplot as plt

plt.imshow(frame)

# %%
import matplotlib.pyplot as plt
plt.imshow(gray)

# %%
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
print("cv2 file:", cv2.__file__)
print("cv2 version:", cv2.__version__)
print("has data attr:", hasattr(cv2, "data"))
print("first 30 attrs:", [a for a in dir(cv2)[:30]])
# Out:
# cv2 file: c:\Users\USER\anaconda3\envs\haar_env\lib\site-packages\cv2.cp310-win_amd64.pyd
# cv2 version: 4.12.0
# has data attr: False
# first 30 attrs: ['ACCESS_FAST', 'ACCESS_MASK', 'ACCESS_READ', 'ACCESS_RW', 'ACCESS_WRITE', 'ADAPTIVE_THRESH_GAUSSIAN_C', 'ADAPTIVE_THRESH_MEAN_C', 'AGAST_FEATURE_DETECTOR_AGAST_5_8', 'AGAST_FEATURE_DETECTOR_AGAST_7_12D', 'AGAST_FEATURE_DETECTOR_AGAST_7_12S', 'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION', 'AGAST_FEATURE_DETECTOR_OAST_9_16', 'AGAST_FEATURE_DETECTOR_THRESHOLD', 'AKAZE', 'AKAZE_DESCRIPTOR_KAZE', 'AKAZE_DESCRIPTOR_KAZE_UPRIGHT', 'AKAZE_DESCRIPTOR_MLDB', 'AKAZE_DESCRIPTOR_MLDB_UPRIGHT', 'AKAZE_create', 'ALGO_HINT_ACCURATE', 'ALGO_HINT_APPROX', 'ALGO_HINT_DEFAULT', 'AffineFeature', 'AffineFeature_create', 'AffineTransformer', 'AgastFeatureDetector', 'AgastFeatureDetector_AGAST_5_8', 'AgastFeatureDetector_AGAST_7_12d', 'AgastFeatureDetector_AGAST_7_12s', 'AgastFeatureDetector_NONMAX_SUPPRESSION']

# %%
import cv2

face_cascade = cv2.CascadeClassifier(
    r"haar/haarcascade_frontalface_default.xml"
)

# %%
if face_cascade.empty():
    raise IOError("Haar cascade file not loaded")
else:
    print("Haar cascade file is loaded")
# Out:
# Haar cascade file is loaded

# %%
faces = face_cascade.detectMultiScale(gray)

# %%
for (x, y, w, h) in faces:
        cv2.rectangle(
            frame,
            (x, y),
            (x + w, y + h),
            (0, 255, 0),
            2
        )

# %%
cv2.imshow("Face Detection", frame)

# %%
print(faces)
# Out:
# [[401 379  70  70]
#  [304 242 132 132]]

# %%
plt.imshow(faces)

# %%
import cv2

cap = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier(
    r"haar/haarcascade_frontalface_default.xml"
)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5
    )

    for (x, y, w, h) in faces:
        cv2.rectangle(
            frame,
            (x, y),
            (x + w, y + h),
            (0, 255, 0),
            2
        )

    cv2.imshow("Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
img=cv2.VideoCapture(0)
ret,frame=img.read()



faces = face_cascade.detectMultiScale(
    frame,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)
for (x, y, w, h) in faces:
        center = (x + w // 2, y + h // 2)
        radius = max(w, h) // 2
        cv2.circle(frame, center, radius, (0, 255, 0), 3)

    # Convert BGR to RGB for matplotlib
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

plt.imshow(frame_rgb)

# %%
img.release()
cv2.destroyAllWindows()

# %%
import cv2
img = cv2.imread('img.jpg')


faces = face_cascade.detectMultiScale(
    img,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)
for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)  # green rectangle

    # Display the result
import matplotlib.pyplot as plt
frame_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(frame_rgb)

# %%
import cv2
img = cv2.imread('gettyimages-498012796-612x612.jpg')


faces = face_cascade.detectMultiScale(
    img,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)
for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0,255, 0), 2)  # green rectangle

    # Display the result
import matplotlib.pyplot as plt
frame_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(frame_rgb)

# %%
import cv2

# Load Haar Cascade for face detection
face_cascade=cv2.CascadeClassifier(
    r"haar/haarcascade_frontalface_default.xml"
)

# Open video
cap = cv2.VideoCapture("people.mp4")

while True:
        ret, frame = cap.read()  # Read frame from video
        if not ret:
            break  # End of video

        # Convert to grayscale for Haar Cascade
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces
        faces = face_cascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30)
        )

        # Draw rectangles around faces
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Display live frame
        cv2.imshow("Face Detection", frame)

        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      17 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      19 # Detect faces
# ---> 20 faces = face_cascade.detectMultiScale(
#      21     gray,
#      22     scaleFactor=1.1,
#      23     minNeighbors=5,
#      24     minSize=(30, 30)
#      25 )
#      27 # Draw rectangles around faces
#      28 for (x, y, w, h) in faces:
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Load Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(
    r"haar/haarcascade_frontalface_default.xml"
)

# Open video
cap = cv2.VideoCapture("people.mp4")

# Optional: parameters to filter false positives
scaleFactor = 1.1       # Smaller increments detect smaller faces
minNeighbors = 6        # Higher value reduces false positives
minSize = (50, 50)      # Ignore very small regions (likely background edges)
maxSize = (300, 300)    # Optional: ignore very large detections if not needed


while True:
    ret, frame = cap.read()
    frame = cv2.resize(frame, (640, 480))
    if not ret:
        break

    # Convert to grayscale for Haar Cascade
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Optional: Apply slight blur to reduce background edges detection
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Detect faces
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=scaleFactor,
        minNeighbors=minNeighbors,
        minSize=minSize,
        maxSize=maxSize
    )

    # Draw rectangles around faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display live frame
    cv2.imshow("Face Detection", frame)

    # Press 'q' to quit
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2

# Load pretrained YOLO face model
model = YOLO("model.pt")  # face-specific model

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO inference
    results = model(frame, conf=0.5)

    # Loop over detections
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)

    cv2.imshow("YOLO Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
from ultralytics import YOLO
import cv2

# Load pretrained YOLO face model
model = YOLO("model.pt")  # face-specific model

cap = cv2.VideoCapture("people.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO inference
    results = model(frame, conf=0.5)

    # Loop over detections
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)

    cv2.imshow("YOLO Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 384x640 4 faces, 88.8ms
# Speed: 17.6ms preprocess, 88.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 99.7ms
# Speed: 3.3ms preprocess, 99.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 79.9ms
# Speed: 3.9ms preprocess, 79.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 81.1ms
# Speed: 3.9ms preprocess, 81.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 77.8ms
# Speed: 3.8ms preprocess, 77.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 89.7ms
# Speed: 4.1ms preprocess, 89.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 76.0ms
# Speed: 4.9ms preprocess, 76.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 faces, 72.7ms
# ...

# %%
cap.release()
cv2.destroyAllWindows()
