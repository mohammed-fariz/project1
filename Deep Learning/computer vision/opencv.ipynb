# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("car.jpeg",1)

# %%
cv2.imshow('image',img)

# %%
img
# Out:
# array([[[  0,  11,  60],
#         [  0,  13,  62],
#         [  1,  15,  67],
#         ...,
#         [  8,  10,  10],
#         [  6,   8,   8],
#         [  4,   6,   6]],
#
#        [[  2,  15,  67],
#         [  3,  17,  69],
#         [  6,  20,  72],
#         ...,
#         [  8,  11,   9],
#         [  6,   9,   7],
#         [  4,   7,   5]],
#
#        [[  9,  23,  76],
#         [ 10,  24,  77],
#         [ 12,  25,  81],
#         ...,
#         [  8,  11,   9],
#         [  6,   9,   7],
#         [  4,   7,   5]],
#
#        ...,
#
#        [[ 19,  18,  20],
#         [ 16,  17,  21],
#         [ 13,  16,  21],
#         ...,
#         [ 24,  39,  88],
#         [ 40,  59, 110],
#         [ 51,  71, 126]],
#
#        [[ 24,  23,  19],
#         [ 23,  22,  18],
#         [ 20,  21,  19],
#         ...,
#         [ 21,  32,  82],
#         [ 26,  40,  93],
#         [ 28,  43,  99]],
#
#        [[ 28,  28,  22],
#         [ 27,  27,  21],
#         [ 23,  24,  20],
# ...

# %%
plt.imshow(img)

# %%
img2=cv2.imread("car.jpeg",0)

# %%
r_image=cv2.resize(img2,(300,300))
plt.imshow(r_image)

# %%
img3=cv2.imshow('resized_image',r_image)

# %%
plt.imshow(img2)

# %%
blur=cv2.GaussianBlur(img,(7,7),0)
plt.imshow(blur)

# %%
avg_blur=cv2.blur(img,(3,3))
plt.imshow(avg_blur)

# %%
median_blur=cv2.medianBlur(img,3)

plt.imshow(median_blur)

# %%
motion_blur=cv2.filter2D(img,-1,(3,3))
plt.imshow(motion_blur)

# %%
bilaterlfilter_blur=cv2.bilateralFilter(img,d=9,sigmaColor=75,sigmaSpace=75)
plt.imshow(bilaterlfilter_blur)

# %%
edges=cv2.Canny(img,50,100)
plt.imshow(edges)

# %%
ret,thre= cv2.threshold(img2, 100, 300, cv2.THRESH_BINARY)
plt.imshow(thre,cmap='gray')

# %%
THRES=cv2.adaptiveThreshold(img2, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11, 2)
plt.imshow(THRES)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
txt=cv2.imread('download.png')
plt.imshow(txt)

# %%
import pytesseract

# %%
import easyocr

reader = easyocr.Reader(['en'])
result = reader.readtext("download.png")

for _, text, _ in result:
    print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\Users\USER\anaconda3\envs\haar_env\lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Image To
# Text
# Converter
# Tools

# %%
import easyocr

result=reader.readtext("handwrt.jpeg")
for _,text,_ in result:
    print(text)
# Out:
# c:\Users\USER\anaconda3\envs\haar_env\lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# We Stact With Good
# Because
# all
# businesses should
# be
# doing
# Soml
# Ood
# -thing

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Users\USER\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"


print(pytesseract.get_tesseract_version())
# Out:
# 5.5.0.20241111

# %%
roi = txt[50:120, 100:400]
text = pytesseract.image_to_string(roi, config="--psm 7")
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\USER\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"
print(text)
# Out:
# erter TT

# %%
text=pytesseract.image_to_string(txt)

# %%
from pdf2image import convert_from_path

pages = convert_from_path(
    "cv.pdf",
    dpi=300,
    poppler_path=r"C:\poppler\Library\bin"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\USER\anaconda3\envs\haar_env\lib\site-packages\pdf2image\pdf2image.py:581, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     580     env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 581 proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     583 try:
#
# File c:\Users\USER\anaconda3\envs\haar_env\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# ...

# %%
import pytesseract
text = pytesseract.image_to_string(pages[0])
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pytesseract
# ----> 2 text = pytesseract.image_to_string(pages[0])
#       3 print(text)
#
# NameError: name 'pages' is not defined
