# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("transactions_data.csv")

# %%
df.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df2= pd.read_csv("users_data.csv")

# %%
df2.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# ...

# %%
data= pd.merge(df, df2, how="outer")

# %%
data.head()
# Out:
#    id date  client_id  card_id amount use_chip  merchant_id merchant_city  \
# 0   0  NaN        NaN      NaN    NaN      NaN          NaN           NaN
# 1   1  NaN        NaN      NaN    NaN      NaN          NaN           NaN
# 2   2  NaN        NaN      NaN    NaN      NaN          NaN           NaN
# 3   3  NaN        NaN      NaN    NaN      NaN          NaN           NaN
# 4   4  NaN        NaN      NaN    NaN      NaN          NaN           NaN
#
#   merchant_state  zip  ...  birth_month  gender                      address  \
# 0            NaN  NaN  ...          3.0    Male              858 Plum Avenue
# 1            NaN  NaN  ...          4.0  Female               113 Burns Lane
# 2            NaN  NaN  ...          8.0    Male           6035 Forest Avenue
# 3            NaN  NaN  ...         12.0    Male               840 Elm Avenue
# 4            NaN  NaN  ...          3.0  Female  6016 Little Creek Boulevard
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 25 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   date               object
#  2   client_id          int64
#  3   card_id            int64
#  4   amount             object
#  5   use_chip           object
#  6   merchant_id        int64
#  7   merchant_city      object
#  8   merchant_state     object
#  9   zip                float64
#  10  mcc                int64
#  11  errors             object
#  12  current_age        float64
#  13  retirement_age     float64
#  14  birth_year         float64
#  15  birth_month        float64
#  16  gender             object
#  17  address            object
#  18  latitude           float64
#  19  longitude          float64
#  20  per_capita_income  object
#  21  yearly_income      object
#  22  total_debt         object
#  23  credit_score       float64
# ...

# %%
data.shape
# Out:
# (13305915, 25)

# %%
data.isnull().sum()
# Out:
# id                          0
# date                        0
# client_id                   0
# card_id                     0
# amount                      0
# use_chip                    0
# merchant_id                 0
# merchant_city               0
# merchant_state        1563700
# zip                   1652706
# mcc                         0
# errors               13094522
# current_age          13305915
# retirement_age       13305915
# birth_year           13305915
# birth_month          13305915
# gender               13305915
# address              13305915
# latitude             13305915
# longitude            13305915
# per_capita_income    13305915
# yearly_income        13305915
# total_debt           13305915
# credit_score         13305915
# num_credit_cards     13305915
# dtype: int64

# %%
merged = pd.merge(transactions, users, on='client_id', how='inner')
