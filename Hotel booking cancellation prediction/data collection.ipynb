# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
df['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
sns.countplot(x='country',data=df)
plt.xticks(rotation=180)
plt.show()

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
#        'ISL', 'UZB', 'NPL', 'BHS', 'MAC', 'TGO', 'TWN', 'DJI', 'STP',
#        'KNA', 'ETH', 'IRQ', 'HND', 'RWA', 'KHM', 'MCO', 'BGD', 'IMN',
#        'TJK', 'NIC', 'BEN', 'VGB', 'TZA', 'GAB', 'GHA', 'TMP', 'GLP',
#        'KEN', 'LIE', 'GNB', 'MNE', 'UMI', 'MYT', 'FRO', 'MMR', 'PAN',
#        'BFA', 'LBY', 'MLI', 'NAM', 'BOL', 'PRY', 'BRB', 'ABW', 'AIA',
#        'SLV', 'DMA', 'PYF', 'GUY', 'LCA', 'ATA', 'GTM', 'ASM', 'MRT',
#        'NCL', 'KIR', 'SDN', 'ATF', 'SLE', 'LAO'], dtype=object)

# %%
sns.barplot(df['country'])
# Out:
# <Axes: ylabel='country'>

# %%
df['country'].describe()
# Out:
# count     118902
# unique       177
# top          PRT
# freq       48590
# Name: country, dtype: object

# %%
sns.boxplot(x=df['country'])
# Out:
# <Axes: xlabel='country'>

# %%
top_countries = df['country'].value_counts().nlargest(30)
top_countries.plot(kind='bar')
plt.title('Top 10 Countries by Count')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries by Count')

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer(strategy='most_frequent')

# %%
df[['country']]=imputer.fit_transform(df[['country']])

# %%
df['country'].isnull().sum()
# Out:
# 0

# %% [markdown]
# country feature having 488 null values so i used simple imputer method to fill null values using mode

# %%
df['children'].isnull().sum()
# Out:
# 4

# %%
sns.kdeplot(df['children'])
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
df['children'].skew()
# Out:
# 4.11258954232252

# %%
df['children']=df['children'].fillna(df['children'].median())

# %%
df['agent'].isnull().sum()/len(df)*100
# Out:
# 13.686238378423655

# %%
sns.kdeplot(df['agent'])
# Out:
# <Axes: xlabel='agent', ylabel='Density'>

# %%
df['agent'].skew()
# Out:
# 1.089385636108877

# %% [raw]
# Even though the skew is 1 (mildly right-skewed), agent IDs are just labels, not values with a measurable average or middle.
#
# Filling with the median would create a meaningless "agent" (e.g., 241.0) who doesn’t exist — which wouldn’t help your model.

# %%
df.fillna({'agent': 0}, inplace=True)

# %%
df['company'].isnull().sum()/len(df)*100
# Out:
# 94.30689337465449

# %%
df['has_company'] = df['company'].notnull().astype(int)

# %%
df['has_company'].value_counts()
# Out:
# has_company
# 0    112593
# 1      6797
# Name: count, dtype: int64

# %%
df.drop('company',axis=1,inplace=True)

# %% [raw]
# The company column contains 94% missing values. It represents whether a booking was made through a company or not, which may influence the likelihood of cancellation. To retain this useful information without keeping the sparse ID values, I created a new binary feature has_company, where:
#
# 1 indicates the booking was made through a company (i.e., the value is not null)
#
# 0 indicates the booking was made without a company (i.e., the value is null)
#
# After extracting this information, I dropped the original company column from the dataset, as the remaining ID values were not useful for modeling.

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# has_company                       0
# dtype: int64

# %%
cancel_rate = df.groupby('hotel')['is_canceled'].mean()

# %%
cancel_rate.plot(kind='pie', autopct='%1.1f%%')
plt.title('Cancellation Rate by Hotel Type')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate by Hotel Type')

# %%
sns.barplot(data=df, x='hotel', y='is_canceled',hue='hotel')
# Out:
# <Axes: xlabel='hotel', ylabel='is_canceled'>

# %%
numerical_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests'
]


plt.figure(figsize=(18, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 4, i) 
    sns.boxplot(y=df[col])
    plt.title(col)
    plt.tight_layout()

plt.suptitle("Boxplots of Numerical Features", fontsize=16, y=1.02)
# Out:
# Text(0.5, 1.02, 'Boxplots of Numerical Features')

# %% [raw]
# univariate analysis

# %%
categorical_cols = [
    'hotel', 'arrival_date_month', 'meal', 'market_segment', 'distribution_channel',
    'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type',
    'reservation_status'
]
for col in categorical_cols:
    
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col,order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
 
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=90)

# %%
numerical_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies',  'is_repeated_guest', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests','has_company'
]



plt.figure(figsize=(18, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 4, i) 
    sns.kdeplot(x=df[col])
    plt.title(col)
    plt.tight_layout()

plt.suptitle("Distibution  of Numerical Features", fontsize=16, y=1.02)
# Out:
# Text(0.5, 1.02, 'Distibution  of Numerical Features')

# %% [markdown]
# bivariate analysis

# %%
categorical_cols = ['hotel', 'arrival_date_month', 'meal', 'market_segment', 'distribution_channel',
                    'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type',
                    'reservation_status']

# %%
for col in categorical_cols:
    
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, palette="Set2",hue='is_canceled', order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=90)

# %%
numerical_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies',  'is_repeated_guest', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests','has_company'
]


plt.figure(figsize=(20, 19))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 4, i+1)  # Arrange plots in a 4x3 grid
    sns.scatterplot(x='is_canceled', y=col, data=df)
    plt.title(f"Countplot of {col}")
    
    plt.suptitle("Relationship Between Numerical Features and Cancellation Status", fontsize=16, y=1.02)

# %%
plt.figure(figsize=(13,8))
sns.heatmap(df[['is_canceled','lead_time',  'arrival_date_year','arrival_date_week_number','stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies',  'is_repeated_guest', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests','has_company']].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
numerical_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies',  'is_repeated_guest', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests','has_company'
]


plt.figure(figsize=(20, 19))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 4, i+1)  # Arrange plots in a 4x3 grid
    sns.scatterplot(x='is_canceled', y=col, data=df,hue='hotel')
    plt.title(f"Countplot of {col}")
  
    plt.suptitle("Relationship Between Numerical Features and Cancellation Status", fontsize=16, y=1.02)

# %%
sns.scatterplot(data=df,x='is_canceled',y='arrival_date_year')
# Out:
# <Axes: xlabel='is_canceled', ylabel='arrival_date_year'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='arrival_date_month')
# Out:
# <Axes: xlabel='is_canceled', ylabel='arrival_date_month'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='arrival_date_week_number')
# Out:
# <Axes: xlabel='is_canceled', ylabel='arrival_date_week_number'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='adults')
# Out:
# <Axes: xlabel='is_canceled', ylabel='adults'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='children')
# Out:
# <Axes: xlabel='is_canceled', ylabel='children'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='babies')
# Out:
# <Axes: xlabel='is_canceled', ylabel='babies'>

# %%
sns.scatterplot(data=df,x='is_canceled',y='adr')
# Out:
# <Axes: xlabel='is_canceled', ylabel='adr'>

# %% [markdown]
# df=df.drop(['arrival_date_year','arrival_date_month','arrival_date_week_number','adults','children','babies','adr'],axis=0)

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,MinMaxScaler,StandardScaler

# %%
X = df.drop('is_canceled', axis=1)
y = df['is_canceled']

# %% [markdown]
# # from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
# # label_encoder = LabelEncoder()
# # categorical_columns = ['hotel', 'arrival_date_month', 'meal', 'country',
# #                        'market_segment', 'distribution_channel',
# #                        'reserved_room_type', 'assigned_room_type',
# #                        'deposit_type', 'customer_type', 'reservation_status']
#
# # for col in categorical_columns:
# #     df[col] = label_encoder.fit_transform(df[col])
#
# # numerical_cols = [
# #     'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
# #     'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations',
# #     'previous_bookings_not_canceled', 'booking_changes',
# #     'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
# #     'total_of_special_requests', 'has_company'
# # ]
# scaler = StandardScaler()
# X_numerical = df[categorical_columns]
# X_scaled =scaler.fit_transform(X_numerical)

# %%
label_encoder = LabelEncoder()

# %%
categorical_columns = ['hotel', 'arrival_date_month', 'meal', 'country', 
                       'market_segment', 'distribution_channel', 
                       'reserved_room_type', 'assigned_room_type',
                       'deposit_type', 'customer_type', 'reservation_status']  

for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.drop('reservation_status_date', axis=1, inplace=True)

# %%
scaler = MinMaxScaler()  
X_numerical = df[categorical_columns]
X_scaled = scaler.fit_transform(X_numerical)

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %%
selector = SelectKBest(score_func=chi2, k=10)
selector.fit_transform(X_scaled, y)
X_scaled = pd.DataFrame(X_scaled, columns=categorical_columns)

# %%
selected_features_indices = selector.get_support(indices=True)
selected_features_names = [categorical_columns[i] for i in selected_features_indices]
selected_features_names
# Out:
# ['hotel',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=42)

# %%
chi_scores=chi2(X_scaled,y)

# %%
chi_scores
# Out:
# (array([1.47877368e+03, 5.48853008e-02, 1.91649319e+01, 1.03946549e+03,
#         1.95532601e+01, 2.67120926e+02, 1.45036407e+02, 8.92938395e+02,
#         1.17575847e+04, 2.87866091e+01, 1.91489067e+04]),
#  array([0.00000000e+000, 8.14770623e-001, 1.19895905e-005, 4.74302685e-228,
#         9.78336397e-006, 4.81285820e-060, 2.10863535e-033, 3.36461602e-196,
#         0.00000000e+000, 8.08079000e-008, 0.00000000e+000]))

# %%
chi_values=pd.Series(chi_scores[0],index=X_scaled.columns)

# %%
chi_values.sort_values(ascending=False,inplace=True)

# %%
chi_values.plot.bar()
# Out:
# <Axes: >

# %%
p_values=pd.Series(chi_scores[1],index=X_scaled.columns)
p_values.sort_values(ascending=False,inplace=True)
p_values.plot.bar()
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.feature_selection import chi2

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.99
# Precision:1.00
# Recall:0.97
# F1score:0.99

# %%
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=ExtraTreeClassifier()
model.fit(x_train,y_train)
# Out:
# ExtraTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=AdaBoostClassifier()
model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=GradientBoostingClassifier()
model.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=BaggingClassifier()
model.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=BernoulliNB()
model.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.99
# Precision:1.00
# Recall:0.97
# F1score:0.99

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis

# %%
model=MLPClassifier()
model.fit(x_train,y_train)
# Out:
# MLPClassifier()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=LinearDiscriminantAnalysis()
model.fit(x_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.99
# Precision:1.00
# Recall:0.97
# F1score:0.99

# %%
model=QuadraticDiscriminantAnalysis(reg_param=1,)
model.fit(x_train,y_train)
# Out:
# QuadraticDiscriminantAnalysis(reg_param=1)

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred,zero_division=0)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.63
# Precision:0.00
# Recall:0.00
# F1score:0.00

# %%
from sklearn.metrics import confusion_matrix

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
tn,fp,fn,tp=cf.ravel()

# %%
print(tn,fp,fn,tp)
# Out:
# 22478 0 13339 0

# %%
sns.heatmap(cf,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# in this confusion matrix o mean not cancel and 1 mean cancel

# %%
df_full = x.copy()
df_full['target'] = y 
corr_matrix = df_full.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 df_full = x.copy()
#       2 df_full['target'] = y
#       3 corr_matrix = df_full.corr()
#
# NameError: name 'x' is not defined

# %%
correlation_with_target = corr_matrix['target'].sort_values(ascending=False)

# %%
print("Correlation of Features with Target:\n")
print(correlation_with_target)

# %%
from sklearn.feature_selection import f_classif

# %%
numerical_cols = [
    'lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
    'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations',
    'previous_bookings_not_canceled', 'booking_changes',
    'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
    'total_of_special_requests', 'has_company' ]

# %%
scaler = MinMaxScaler()  
X_numerical = df[numerical_cols]
X_scaled = scaler.fit_transform(X_numerical)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=42)

# %%
selector = SelectKBest(score_func=f_classif, k=10)
selector.fit_transform(X_scaled, y)
X_scaled = pd.DataFrame(X_scaled, columns=numerical_cols)

# %%
selected_features_indices = selector.get_support(indices=True)
selected_features_names = [numerical_cols[i] for i in selected_features_indices]
selected_features_names

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis,QuadraticDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier

# %%
model=LogisticRegression()
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=AdaBoostClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GradientBoostingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=KNeighborsClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BernoulliNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=MLPClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=LinearDiscriminantAnalysis()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=QuadraticDiscriminantAnalysis(reg_param=1)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BaggingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=ExtraTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=XGBClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
X=df[[ 
       'hotel', 'lead_time', 'arrival_date_year',
       'arrival_date_week_number', 'arrival_date_day_of_month',
       'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children',
       'babies', 'meal', 'country', 'market_segment', 'distribution_channel',
       'is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'reserved_room_type',
       'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
       'days_in_waiting_list', 'customer_type', 'adr',
       'required_car_parking_spaces', 'total_of_special_requests',
       'reservation_status', 'has_company'
]]

# %%
from sklearn.feature_selection import RFE
selector = RFE(estimator=model, n_features_to_select=10)
selector.fit_transform(X,y)

# %%
selected_features = X.columns[selector.support_]
print("Selected Features by RFE:")
print(selected_features)

# %% [markdown]
# reservation_status is very highly negatively correlated (-0.91) with target.

# %%
X_selected = X[selected_features]

# %%
X_selected= X[selected_features].drop('reservation_status', axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(X_selected,y,test_size=0.3,random_state=42)

# %%
model=LogisticRegression(solver='liblinear',max_iter=5000)
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=AdaBoostClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GradientBoostingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=KNeighborsClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BernoulliNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=MLPClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=LinearDiscriminantAnalysis()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=QuadraticDiscriminantAnalysis(reg_param=1)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BaggingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=XGBClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=ExtraTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
from sklearn.feature_selection import RFE
selector = RFE(estimator=model, n_features_to_select=20)
selector.fit_transform(X,y)

# %%
selected_features = X.columns[selector.support_]
print("Selected Features by RFE:")
print(selected_features)

# %%
X_selected = X[selected_features]

# %%
x_train,x_test,y_train,y_test=train_test_split(X_selected,y,test_size=0.3,random_state=42)

# %%
model=LogisticRegression(solver='liblinear',max_iter=5000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=AdaBoostClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GradientBoostingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=KNeighborsClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BernoulliNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=MLPClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=BaggingClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=LinearDiscriminantAnalysis()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=QuadraticDiscriminantAnalysis(reg_param=1)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=XGBClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=ExtraTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
model=RandomForestClassifier()

# %%
param_grid= {
    'n_estimators': [100, 200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5]
}

# %%
grid_search=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(x_train,y_train)

# %%
grid_search.best_params_

# %%
y_pred=grid_search.best_estimator_.predict(x_test)

# %%
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')

# %%
model=LogisticRegression()

param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs'],
    'max_iter': [100, 200]
}
grid_search=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10], 'max_iter': [100, 200],
#                          'solver': ['liblinear', 'lbfgs']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'C': 0.01, 'max_iter': 100, 'solver': 'liblinear'}

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.99
# Precision:1.00
# Recall:0.97
# F1score:0.99

# %%
model=DecisionTreeClassifier()

# %%
param_grid= { 
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 20],
    'min_samples_split': [2, 5, 10]
}
grid_search=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10}

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=GradientBoostingClassifier()
param_grid= {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}
grid_search=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')
grid_search.fit(x_train,y_train)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [3, 5],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=AdaBoostClassifier()

# %%
param_grid={
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1, 1.0]
}
grid_search=GridSearchCV(model,param_grid,cv=5,scoring='f1')
grid_search.fit(x_train,y_train)
# Out:
# {'learning_rate': 1.0, 'n_estimators': 50}

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}

# %%
y_pred=grid_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model = RandomForestClassifier()
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 20],
    'min_samples_split': [2, 5, 10]
}

# %%
random_search=RandomizedSearchCV(model,param_dist,cv=5,scoring='accuracy')
random_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [5, 10, 20],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='accuracy')

# %%
random_search.best_params_
# Out:
# {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 20}

# %%
y_pred=random_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=LogisticRegression()

# %%
param_dist={
    'C': [0.001, 0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 200, 300]
}

# %%
random_search=GridSearchCV(model,param_dist,cv=5,scoring='accuracy')
random_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 15, 20],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
random_search.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}

# %%
y_pred=random_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

# %%
model=LogisticRegression()

# %%
param_dist = {
    'C': [0.1, 1, 10],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 200]
}

# %%
random_search=HalvingGridSearchCV(model,param_dist,cv=5,scoring='accuracy')
random_search.fit(x_train,y_train)
# Out:
# HalvingGridSearchCV(estimator=LogisticRegression(),
#                     param_grid={'C': [0.1, 1, 10], 'max_iter': [100, 200],
#                                 'solver': ['liblinear', 'saga']},
#                     scoring='accuracy')

# %%
random_search.best_params_
# Out:
# {'C': 0.1, 'max_iter': 200, 'solver': 'liblinear'}

# %%
y_pred=random_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 0.99
# Precision:1.00
# Recall:0.97
# F1score:0.99

# %%
model=RandomForestClassifier()
param_dist= {
    'n_estimators': [100, 200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5]
}

# %%
random_search=HalvingGridSearchCV(model,param_dist,cv=5,scoring='accuracy')
random_search.fit(x_train,y_train)
# Out:
# HalvingGridSearchCV(estimator=RandomForestClassifier(),
#                     param_grid={'max_depth': [10, 20],
#                                 'min_samples_split': [2, 5],
#                                 'n_estimators': [100, 200]},
#                     scoring='accuracy')

# %%
random_search.best_params_
# Out:
# {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}

# %%
y_pred=random_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
model=DecisionTreeClassifier()

# %%
param_dist={
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [2, 5, 10]
}

# %%
from sklearn.model_selection import HalvingRandomSearchCV

# %%
random_search=HalvingRandomSearchCV(model,param_dist,cv=5,scoring='accuracy')
random_search.fit(x_train,y_train)
# Out:
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 24 is smaller than n_iter=4178. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# HalvingRandomSearchCV(estimator=DecisionTreeClassifier(),
#                       param_distributions={'criterion': ['gini', 'entropy'],
#                                            'max_depth': [5, 10, 15, 20],
#                                            'min_samples_split': [2, 5, 10]},
#                       scoring='accuracy')

# %%
random_search.best_params_
# Out:
# {'min_samples_split': 5, 'max_depth': 5, 'criterion': 'gini'}

# %%
y_pred=random_search.best_estimator_.predict(x_test)
Accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1score=f1_score(y_test,y_pred)
print(f"Accuracy: {Accuracy:.2f}")
print(f'Precision:{precision:.2f}')
print(f'Recall:{recall:.2f}')
print(f'F1score:{f1score:.2f}')
# Out:
# Accuracy: 1.00
# Precision:1.00
# Recall:1.00
# F1score:1.00

# %%
from sklearn.model_selection import cross_val_score

# %%
model=LogisticRegression()
scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
# Out:
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-validation accuracy scores: [0.71567971 0.76656336 0.82640925 0.68192478 0.70165005]
# Average accuracy: 0.7384454309406149

# %%
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)

# %%
model=RandomForestClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.99987436 1.         1.         0.99991624 0.99962308]
# Average accuracy: 0.9998827372476757

# %%
model=DecisionTreeClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Average accuracy: 1.0

# %%
model=GradientBoostingClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Average accuracy: 1.0

# %%
model=AdaBoostClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Average accuracy: 1.0

# %%
model=KNeighborsClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.67706676 0.56977134 0.56059972 0.49995812 0.57609515]
# Average accuracy: 0.5766982159309825

# %%
model=GaussianNB()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.99141469 0.99556077 0.96503057 0.99233604 0.92457492]
# Average accuracy: 0.9737833989446353

# %%
model=BernoulliNB()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.98684982 0.98190803 0.9909959  0.99246168 0.99321551]
# Average accuracy: 0.9890861881229582

# %%
model=MLPClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.99757099 0.98215931 0.98957199 0.99174973 0.99995812]
# Average accuracy: 0.9922020269704331

# %%
model=LinearDiscriminantAnalysis()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.99020018 0.98249435 0.99120529 0.99195913 0.99350867]
# Average accuracy: 0.9898735237457073

# %%
model=QuadraticDiscriminantAnalysis()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 0 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 1 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 0 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 1 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 0 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 1 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 0 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 1 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 0 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# C:\Users\T70\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:1024: LinAlgWarning: The covariance matrix of class 1 is not full rank. Increasing the value of parameter `reg_param` might help reducing the collinearity.
#   warnings.warn(
# Cross-validation accuracy scores: [0.99229416 0.98911132 0.97055867 0.99317363 0.80123963]
# Average accuracy: 0.9492754837088533

# %%
model=ExtraTreeClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [0.90518469 1.         0.95095904 0.65327917 0.96586816]
# Average accuracy: 0.8950582125806182

# %%
model=XGBClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Average accuracy: 1.0

# %%
model=BaggingClassifier()

# %%
scores= cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Average accuracy:", scores.mean())
folds = [1, 2, 3, 4, 5]
plt.plot(folds, scores, marker='o')
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.title("Cross-Validation Accuracy per Fold")
plt.grid(True)
# Out:
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Average accuracy: 1.0

# %%
plt.scatter(y[:,0],Y[:,1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[574], line 1
# ----> 1 plt.scatter(y[:,0],Y[:,1])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1163, in Series._get_with(self, key)
#    1158     raise TypeError(
#    1159         "Indexing a Series with DataFrame is not "
#    1160         "supported, use the appropriate DataFrame column"
#    1161     )
#    1162 elif isinstance(key, tuple):
# -> 1163     return self._get_values_tuple(key)
#    1165 elif not is_list_like(key):
#    1166     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1167     return self.loc[key]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1207, in Series._get_values_tuple(self, key)
#    1204     return result
#    1206 if not isinstance(self.index, MultiIndex):
# -> 1207     raise KeyError("key of type tuple not found and not a MultiIndex")
#    1209 # If key is contained, would have returned by now
#    1210 indexer, new_index = self.index.get_loc_level(key)
#
# KeyError: 'key of type tuple not found and not a MultiIndex'

# %%
plt.show()
